# %%
name = "  Samuel Umtiti "

# %%
name.lower()
# Out:
# 'samuel umtiti'

# %%
name.upper()
# Out:
# 'SAMUEL UMTITI'

# %%
name.endswith("ti")
# Out:
# True

# %%
name.startswith("a")
# Out:
# False

# %%
name.strip()
# Out:
# 'Samuel Umtiti'

# %%
txt = "something, halding, trent, 5, universe"

# %%
txt.split(",")
# Out:
# ['something', ' halding', ' trent', ' 5', ' universe']
